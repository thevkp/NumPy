# %% [markdown]
# # 🧠 Sigmoid Function: Introduction & Uses
#
# ---
#
# ## 📌 What is the Sigmoid Function?
#
# The **sigmoid function** is a mathematical function that maps any real number into a value between **0 and 1**.
#
# ### 🔣 Formula:
#
# $$
# \sigma(x) = \frac{1}{1 + e^{-x}}
# $$
#
# This S-shaped (sigmoid) curve is smooth and differentiable, making it a common choice in various computational fields.
#
# ---
#
# ## 📈 Why Use Sigmoid?
#
# ### ✅ Key Properties:
#
# - Output is **bounded** between 0 and 1.
# - **Differentiable** everywhere.
# - **Monotonic** — as input increases, output increases.
# - Has a simple **derivative**:
#
#   $$
#   \sigma'(x) = \sigma(x)(1 - \sigma(x))
#   $$
#
# ---
#
# ## ⚙️ Where Is It Used?
#
# ### 1. **Logistic Regression**
# - Used to model probabilities.
# - Output represents the **probability** of a binary class.
#
# ### 2. **Neural Networks (as Activation Function)**
# - Introduces **non-linearity** in hidden layers.
# - Smooth gradient helps in **gradient-based optimization**.
# - Historically used in early neural nets.
#
# ### 3. **Binary Classification**
# - Converts linear scores to probabilities between 0 and 1.
#
# ---
#
# ## 💻 Python Example
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# def sigmoid(x):
#     return 1 / (1 + np.exp(-x))
#
# x = np.linspace(-10, 10, 100)
# y = sigmoid(x)
#
# plt.plot(x, y)
# plt.title("Sigmoid Function")
# plt.xlabel("x")
# plt.ylabel("σ(x)")
# plt.grid(True)
# plt.show()
# ```
#
# ---
#
# ## ⚠️ Limitations
#
# - **Vanishing gradient** for large |x| (saturates at 0 or 1).
# - Not zero-centered → can slow training in deep networks.
# - Often replaced by ReLU in modern deep learning architectures.
#
# ---
#
# ## ✅ Summary
#
# | Feature        | Description                      |
# |----------------|----------------------------------|
# | Range          | 0 to 1                           |
# | Differentiable | Yes                              |
# | Smooth         | Yes                              |
# | Use Case       | Logistic regression, old NNs     |
#
# Sigmoid helps model **probabilities**, and its simplicity made it a classic — though it's been partially replaced by more modern functions like ReLU and softmax.

# %%
import numpy as np

# %%
def sigmoid(array):
  return 1/(1 + np.exp(-(array)))

a = np.arange(20)
sigmoid(a)
# Out:
# array([0.5       , 0.73105858, 0.88079708, 0.95257413, 0.98201379,
#        0.99330715, 0.99752738, 0.99908895, 0.99966465, 0.99987661,
#        0.9999546 , 0.9999833 , 0.99999386, 0.99999774, 0.99999917,
#        0.99999969, 0.99999989, 0.99999996, 0.99999998, 0.99999999])

# %% [markdown]
# # 🧮 Mean Squared Error (MSE) with NumPy
#
# ---
#
# ## 📌 What is Mean Squared Error?
#
# The **Mean Squared Error (MSE)** is a metric used to measure the average of the **squares of differences** between corresponding elements in two arrays.
#
# > Think of it as a way to measure how "off" your predictions (or approximations) are from the actual values.
#
# ---
#
# ## 🧠 Formula:
#
# Given two arrays:
# - `y_true = [y₁, y₂, ..., yₙ]`
# - `y_pred = [ŷ₁, ŷ₂, ..., ŷₙ]`
#
# The formula is:
#
# $$
# MSE = \frac{1}{n} \sum_{i=1}^{n} (y_i - \hat{y}_i)^2
# $$
#
# ---
#
# ## 💻 NumPy Code Example
#
# ```python
# import numpy as np
#
# # Two example vectors
# y_true = np.array([3, -0.5, 2, 7])
# y_pred = np.array([2.5, 0.0, 2, 8])
#
# # Compute MSE
# mse = np.mean((y_true - y_pred) ** 2)
# print("Mean Squared Error:", mse)
# ```
#
# 🧾 Output:
#
# ```
# Mean Squared Error: 0.375
# ```
#
# ---
#
# ## 🔍 Why Squared?
#
# - Squaring ensures **positive values**, so negative differences don't cancel out.
# - Emphasizes **larger errors** more than smaller ones.
# - Makes the function smooth and differentiable.
#
# ---
#
# ## ⚙️ Applications Outside AI/ML
#
# Even if you're not into AI, MSE is still useful:
# - 📐 Approximating noisy signals
# - 🎮 Measuring control system errors
# - 📊 Comparing predictions vs measurements
# - 🎨 Graphics: comparing pixel intensity values
#
# ---
#
# ## 📦 Bonus: Define Your Own Function
#
# ```python
# def mean_squared_error(a, b):
#     a = np.asarray(a)
#     b = np.asarray(b)
#     return np.mean((a - b) ** 2)
# ```
#
# You just made your own MSE calculator with one line of NumPy magic.
#
# ---
#
# ## 🔚 Summary
#
# | Term | Meaning |
# |------|---------|
# | MSE  | Mean of squared element-wise differences |
# | Output | A single scalar value |
# | Use | Quantifies how different two arrays are |

# %%
# Mean Squared Error
actual = np.random.randint(1, 50, 25)
predicted = np.random.randint(1, 50, 25)

MSE = np.mean((actual - predicted) ** 2)
print(actual)
print(predicted)
print(MSE)
# Out:
# [29  4  1 12 14 39 40 42 23  5  8 15 35 13 48 22  6 36 39 33 41  7  3 40
#  34]
# [ 9 24 28  2 45 20 49 35 46 26 48 33 19 48 32  7  6 23 34 26 26 25 41 20
#  46]
# 428.68

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate sample data
actual = np.random.randint(1, 50, 25)
predicted = np.random.randint(1, 50, 25)

# Compute MSE
MSE = np.mean((actual - predicted) ** 2)
print("Actual:", actual)
print("Predicted:", predicted)
print("MSE:", MSE)

# Plot
plt.figure(figsize=(8, 6))
plt.scatter(actual, predicted, color='blue', label='Predicted Points')
plt.plot([0, 50], [0, 50], color='red', linestyle='--', label='Perfect Prediction Line (y = x)')
plt.title(f'Actual vs Predicted\nMSE = {MSE:.2f}')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.grid(True)
plt.xlim(0, 55)
plt.ylim(0, 55)
plt.show()
# Out:
# Actual: [19 26 41 22 34 13  1 21  2 20 39 23 17 45 49 40 19 21 15 21 11 48  9 28
#  43]
# Predicted: [19 18 10 11 34 10 43 33 22 13 30 10 13 46 42  7  2 11 36  6 24 12 20 39
#  17]
# MSE: 334.2

# %%
import numpy as np
import matplotlib.pyplot as plt

actual_price = np.array([250, 300, 150, 400])
predicted_price = np.array([270, 290, 180, 370])

MSE = np.mean((actual_price - predicted_price) ** 2)
print("MSE:", MSE)

# Plotting
plt.figure(figsize=(8, 6))
plt.scatter(actual_price, predicted_price, color='blue', label='Predicted Points')

# Fix the line to cover full range of prices
min_val = min(actual_price.min(), predicted_price.min()) - 20
max_val = max(actual_price.max(), predicted_price.max()) + 20

plt.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Perfect Prediction Line (y = x)')

plt.title(f'Actual vs Predicted\nMSE = {MSE:.2f}')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.legend()
plt.grid(True)
plt.xlim(min_val, max_val)
plt.ylim(min_val, max_val)
plt.show()
3
# Out:
# MSE: 575.0
# 3

# %%
a = np.array([1,2,3,4,np.nan,6])
b = np.array([2,1,4,np.nan,5,6])

print(a)
print(b)

print(a[np.isnan(a)])
print(b[np.isnan(b)])
# Out:
# [ 1.  2.  3.  4. nan  6.]
# [ 2.  1.  4. nan  5.  6.]
# [nan]
# [nan]

# %%
# Working with missing values
a = np.array([1,2,3,4,np.nan,6])
b = np.array([2,1,4,np.nan,5,6])

mse = np.mean((a - b)  ** 2)
print(mse)

#Boolean indexing to deal with nan values
#isnan(n) returns only the nan value i.e. True if nan
boolean_mask_a = np.isnan(a)
print(boolean_mask_a)

filtered_a = a[boolean_mask_a]
print(filtered_a)

boolean_mask_b = np.isnan(b)
print(boolean_mask_b)

filtered_b = b[boolean_mask_b]
print(filtered_b)
# Out:
# nan
# [False False False False  True False]
# [nan]
# [False False False  True False False]
# [nan]

# %%
#True where both 'a' and 'b' are nan
mask = ~(np.isnan(a)) & ~(np.isnan(b))

filtered_a = a[mask]
filtered_b = b[mask]

print(filtered_a)
print(filtered_b)

mse = np.mean((a - b) ** 2)
print(mse)

mse = np.mean((filtered_a - filtered_b) ** 2)
print(mse)
# Out:
# [1. 2. 3. 6.]
# [2. 1. 4. 6.]
# nan
# 0.75

# %%
plt.figure(figsize=(8,4))
plt.scatter(filtered_a, filtered_b, color='blue')

plt.plot(filtered_a, filtered_b, linestyle='--')

plt.show()

# %%
x = np.arange(11)
y = x

plt.plot(x, y)
plt.show()

# %%
a = np.array([1,2,3,4,np.nan,6])
b = np.array([1,np.nan,2,3,4,5])

mask = ~np.isnan(a) & ~np.isnan(b)
print(mask)

filtered_a = a[mask]
print(filtered_a)

filtered_b = a[mask]
print(filtered_b)

plt.plot(a, b)
plt.show()
# Out:
# [ True False  True  True False  True]
# [1. 3. 4. 6.]
# [1. 3. 4. 6.]

# %%
#Plotting graphs in numpy

x = np.linspace(-10, 10, 100)
y = x
plt.plot(x, y)
plt.show()

# %%
y = x ** 2

plt.plot(x, y)
plt.show()

# %%
y = np.sin(x)
plt.plot(x, y)
plt.show()

# %%
x = np.linspace(0.0001, 10, 100)
y = x * np.log(x)
plt.plot(y)

# %%
x = np.linspace(-10,10,100)
y = 1 / (1 + np.exp(-x))

plt.plot(y)

# %%
#plot a circle centered at origin with radius 5
import numpy as np
import matplotlib.pyplot as plt

r = 5
x = np.linspace(-r, r, 1000)

# Upper and lower semicircles
y_upper = np.sqrt(r**2 - x**2)
y_lower = -np.sqrt(r**2 - x**2)

plt.figure(figsize=(6,6))
plt.plot(x, y_upper, color='blue')
plt.plot(x, y_lower, color='blue')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.title(r'Circle: $x^2 + y^2 = 25$')
plt.gca().set_aspect('equal')  # ensure circle doesn't look squashed
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

theta = np.linspace(0, 2 * np.pi, 1000)
r = 5
h, k = 2, 3  # center of the circle

x = h + r * np.cos(theta)
y = k + r * np.sin(theta)

plt.figure(figsize=(6,6))
plt.plot(x, y, label='Circle')
plt.scatter(h, k, color='red', label='Center')
plt.gca().set_aspect('equal')  # make it look like a circle
plt.grid(True)
plt.title("Circle: (x - 2)² + (y - 3)² = 25")
plt.legend()
plt.show()
